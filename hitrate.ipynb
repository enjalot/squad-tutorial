# %%
# calculate hitrate for the scope
import os
import json
import lancedb
import pandas as pd
import numpy as np
from tqdm import tqdm
from datasets import load_dataset
from sentence_transformers import SentenceTransformer

# %%
# not a very big dataset, 87k rows and <16mb
train = load_dataset("rajpurkar/squad", split="train")
validation = load_dataset("rajpurkar/squad", split="validation")
question_df = pd.concat([pd.DataFrame(train), pd.DataFrame(validation)])
print(question_df.shape)
question_df.head(20)
# Out:
# (98169, 5)
#                           id                     title  \
# 0   5733be284776f41900661182  University_of_Notre_Dame
# 1   5733be284776f4190066117f  University_of_Notre_Dame
# 2   5733be284776f41900661180  University_of_Notre_Dame
# 3   5733be284776f41900661181  University_of_Notre_Dame
# 4   5733be284776f4190066117e  University_of_Notre_Dame
# 5   5733bf84d058e614000b61be  University_of_Notre_Dame
# 6   5733bf84d058e614000b61bf  University_of_Notre_Dame
# 7   5733bf84d058e614000b61c0  University_of_Notre_Dame
# 8   5733bf84d058e614000b61bd  University_of_Notre_Dame
# 9   5733bf84d058e614000b61c1  University_of_Notre_Dame
# 10  5733bed24776f41900661188  University_of_Notre_Dame
# 11  5733bed24776f41900661189  University_of_Notre_Dame
# 12  5733bed24776f4190066118a  University_of_Notre_Dame
# 13  5733bed24776f4190066118b  University_of_Notre_Dame
# 14  5733bed24776f4190066118c  University_of_Notre_Dame
# 15  5733a6424776f41900660f51  University_of_Notre_Dame
# 16  5733a6424776f41900660f4e  University_of_Notre_Dame
# 17  5733a6424776f41900660f4f  University_of_Notre_Dame
# 18  5733a6424776f41900660f50  University_of_Notre_Dame
# 19  5733a6424776f41900660f52  University_of_Notre_Dame
#
#                                               context  \
# 0   Architecturally, the school has a Catholic cha...
# 1   Architecturally, the school has a Catholic cha...
# 2   Architecturally, the school has a Catholic cha...
# 3   Architecturally, the school has a Catholic cha...
# 4   Architecturally, the school has a Catholic cha...
# 5   As at most other universities, Notre Dame's st...
# 6   As at most other universities, Notre Dame's st...
# 7   As at most other universities, Notre Dame's st...
# 8   As at most other universities, Notre Dame's st...
# 9   As at most other universities, Notre Dame's st...
# 10  The university is the major seat of the Congre...
# 11  The university is the major seat of the Congre...
# 12  The university is the major seat of the Congre...
# 13  The university is the major seat of the Congre...
# 14  The university is the major seat of the Congre...
# 15  The College of Engineering was established in ...
# 16  The College of Engineering was established in ...
# 17  The College of Engineering was established in ...
# 18  The College of Engineering was established in ...
# 19  The College of Engineering was established in ...
#
#                                              question  \
# 0   To whom did the Virgin Mary allegedly appear i...
# 1   What is in front of the Notre Dame Main Building?
# 2   The Basilica of the Sacred heart at Notre Dame...
# 3                   What is the Grotto at Notre Dame?
# 4   What sits on top of the Main Building at Notre...
# 5   When did the Scholastic Magazine of Notre dame...
# 6    How often is Notre Dame's the Juggler published?
# 7   What is the daily student paper at Notre Dame ...
# 8   How many student news papers are found at Notr...
# 9   In what year did the student paper Common Sens...
# 10  Where is the headquarters of the Congregation ...
# 11  What is the primary seminary of the Congregati...
# 12        What is the oldest structure at Notre Dame?
# 13  What individuals live at Fatima House at Notre...
# 14         Which prize did Frederick Buechner create?
# 15  How many BS level degrees are offered in the C...
# 16  In what year was the College of Engineering at...
# 17  Before the creation of the College of Engineer...
# 18  How many departments are within the Stinson-Re...
# 19  The College of Science began to offer civil en...
#
#                                               answers
# 0   {'text': ['Saint Bernadette Soubirous'], 'answ...
# 1   {'text': ['a copper statue of Christ'], 'answe...
# 2   {'text': ['the Main Building'], 'answer_start'...
# 3   {'text': ['a Marian place of prayer and reflec...
# 4   {'text': ['a golden statue of the Virgin Mary'...
# 5   {'text': ['September 1876'], 'answer_start': [...
# 6          {'text': ['twice'], 'answer_start': [441]}
# 7   {'text': ['The Observer'], 'answer_start': [598]}
# 8          {'text': ['three'], 'answer_start': [126]}
# 9           {'text': ['1987'], 'answer_start': [908]}
# 10          {'text': ['Rome'], 'answer_start': [119]}
# 11  {'text': ['Moreau Seminary'], 'answer_start': ...
# 12   {'text': ['Old College'], 'answer_start': [234]}
# 13  {'text': ['Retired priests and brothers'], 'an...
# 14  {'text': ['Buechner Prize for Preaching'], 'an...
# 15         {'text': ['eight'], 'answer_start': [487]}
# 16           {'text': ['1920'], 'answer_start': [46]}
# 17  {'text': ['the College of Science'], 'answer_s...
# 18          {'text': ['five'], 'answer_start': [271]}
# 19     {'text': ['the 1870s'], 'answer_start': [155]}

# %%
question_df.iloc[12].answers
# Out:
# {'text': ['Old College'], 'answer_start': [234]}

# %%
scope_id = "scopes-007"
metric = "cosine"

# %%
scope = json.load(open(f"scopes/{scope_id}_{metric}.json"))
scope
# Out:
# {'directory': '/Users/enjalot/latent-scope-data',
#  'scope_id': 'scopes-007',
#  'dataset': 'squad',
#  'metric': 'cosine',
#  'db_uri': '/Users/enjalot/latent-scope-data/squad/lancedb',
#  'table_name': 'scopes-007_cosine',
#  'embedding_id': 'embedding-001',
#  'model_name': 'BAAI/bge-base-en-v1.5'}

# %%
db = lancedb.connect(scope["db_uri"])
table = db.open_table(scope["table_name"])

# %%
table.schema
# Out:
# index: int64
# title: string
# context: string
# x: float
# y: float
# cluster: int64
# raw_cluster: int64
# label: string
# vector: fixed_size_list<item: float>[768]
#   child 0, item: float

# %%
model = SentenceTransformer(scope["model_name"], trust_remote_code=True, device="mps")

# %%
results = []
embeddings = []
topk = 10

for index, row in tqdm(question_df.iterrows(), total=question_df.shape[0]):
    question = row['question']
    question_embedding = model.encode(question)
    embeddings.append(question_embedding)

    # for scopes-006 where we truncated to 64 dimensions
    # Truncate to 64 dimensions and normalize
    # truncated_embedding = question_embedding[:64]
    # normalized_embedding = truncated_embedding / np.linalg.norm(truncated_embedding)
    # question_embedding = normalized_embedding

    search_results = table.search(question_embedding).metric(scope["metric"]).limit(topk).to_list()
    # print("RESULTS", search_results)
    search_results_contexts = [r["context"] for r in search_results]
    match_index = -1
    for i, context in enumerate(search_results_contexts):
        if context == row["context"]:
            match_index = i
            break

    results.append({
        "question": question,
        "results": [s['index'] for s in search_results],
        "match_index": match_index,

    })

# Convert results to a DataFrame for better visualization
results_df = pd.DataFrame(results)
results_df.head()
# Out:
# 100%|██████████| 98169/98169 [28:47<00:00, 56.82it/s]
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                              results  match_index
# 0  [0, 6915, 17590, 268, 6907, 6913, 14154, 6929,...            0
# 1  [29, 38, 12630, 0, 12632, 12914, 3701, 50, 17,...            3
# 2  [38, 28, 0, 14156, 14202, 11426, 8646, 3685, 1...            2
# 3       [0, 38, 28, 17, 3721, 4591, 9, 29, 40, 7239]            0
# 4         [38, 29, 17, 7, 9, 9560, 0, 11436, 30, 27]            6

# %%
results_df.tail(20)
# Out:
#                                                 question  \
# 98149  What is resposible for speeding up or slowing ...
# 98150  What is the only form potential energy can cha...
# 98151  What is the only form kinetic energy can chang...
# 98152  What is preserved in a closed system of forces...
# 98153  What is the force between two locations relate...
# 98154  What is the force called rgarding a potential ...
# 98155             What is sometimes impossible to model?
# 98156  Why are some forces due to that are impossible...
# 98157  What do electrostatic gradiient potentials cre...
# 98158  Tension, compression, and drag are what kind o...
# 98159  In what treatment are nonconservative and cons...
# 98160   What changes macroscopic closed system energies?
# 98161      What is the exchange of heat associated with?
# 98162  What is the law of thermodynamics associated w...
# 98163      What makes energy changes in a closed system?
# 98164  What is the metric term less used than the New...
# 98165  What is the kilogram-force sometimes reffered ...
# 98166  What is a very seldom used unit of mass in the...
# 98167  What seldom used term of a unit of force equal...
# 98168  What is the seldom used force unit equal to on...
#
#                                                  results  match_index
# 98149  [10910, 10907, 10912, 9330, 5049, 10918, 5390,...            8
# 98150  [14646, 14667, 14670, 14650, 14645, 2496, 1464...           -1
# 98151  [14646, 14667, 14670, 14650, 14672, 14645, 146...           -1
# 98152  [20954, 20956, 20923, 20924, 14647, 20955, 209...            0
# 98153  [20925, 20935, 20954, 20926, 20951, 20932, 209...            2
# 98154  [20932, 20925, 20954, 20955, 20942, 20935, 146...            2
# 98155  [13736, 19166, 14429, 19171, 19154, 20955, 191...            5
# 98156  [20955, 20925, 20924, 20949, 20923, 14783, 209...            0
# 98157  [20955, 10930, 14650, 11565, 14674, 15940, 209...            0
# 98158  [20955, 20949, 20951, 20924, 20929, 20925, 209...            0
# 98159  [20956, 20955, 20954, 20924, 20948, 20931, 209...            0
# 98160  [20956, 14670, 14650, 20954, 14647, 14671, 146...            0
# 98161  [6655, 14675, 14676, 14656, 14647, 8832, 20956...            6
# 98162  [14647, 20956, 14675, 14676, 14670, 14677, 146...            1
# 98163  [14670, 14647, 20956, 14675, 20954, 14672, 146...            2
# 98164  [20957, 20921, 20937, 15932, 20938, 20955, 209...            0
# 98165  [20957, 20924, 11755, 11754, 20929, 20926, 209...            0
# 98166  [20957, 11754, 15932, 11755, 13388, 3683, 2093...            0
# 98167  [20957, 20924, 20929, 11754, 20925, 20937, 209...            0
# 98168  [20957, 20929, 20937, 20924, 11754, 20952, 209...            0

# %%
# Count the number of results where match_index is greater than 0
num_matches = (results_df['match_index'] >= 0).sum()

print(f"Number of results where match_index >= 0: {num_matches}")
# Out:
# Number of results where match_index >= 0: 82020

# %%
if not os.path.exists("results"):
    os.makedirs("results")
results_df.to_parquet(f"results/{scope['table_name']}.parquet")

# %%
question_df.iloc[98161]
# Out:
# id                                   5737a9afc3c5551400e51f63
# title                                                   Force
# context     The connection between macroscopic nonconserva...
# question        What is the exchange of heat associated with?
# answers     {'text': ['nonconservative forces', 'nonconser...
# Name: 10562, dtype: object

# %%
# if a saved umap model is available, we can calculate the x,y positions of the questions to save along side

# %%
import pickle
import os

# Construct the path to the UMAP pickle file
scopes_meta = json.load(open(os.path.join(scope["directory"], scope["dataset"], "scopes", f"{scope['scope_id']}.json")))
umap_id = scopes_meta["umap_id"]

umap_file_path = os.path.join(scope["directory"], scope["dataset"], "umaps", f"{umap_id}.pkl")

print(f"loading UMAP model from: {umap_file_path}")

# Load the UMAP model
with open(umap_file_path, 'rb') as f:
    umap_model = pickle.load(f)

print(f"UMAP model loaded")
# Out:
# loading UMAP model from: /Users/enjalot/latent-scope-data/squad/umaps/umap-007.pkl
# Mon Oct 28 13:11:41 2024 Building and compiling search function
# UMAP model loaded

# %%
xy = umap_model.transform(embeddings)
# Out:
# Epochs completed:   0%|            0/30 [00:00]
# 	completed  0  /  30 epochs
# 	completed  3  /  30 epochs
# 	completed  6  /  30 epochs
# 	completed  9  /  30 epochs
# 	completed  12  /  30 epochs
# 	completed  15  /  30 epochs
# 	completed  18  /  30 epochs
# 	completed  21  /  30 epochs
# 	completed  24  /  30 epochs
# 	completed  27  /  30 epochs

# %%
# Read in the UMAP metadata JSON
umap_metadata_path = os.path.join(scope["directory"], scope["dataset"], "umaps", f"{umap_id}.json")
with open(umap_metadata_path, 'r') as f:
    umap_metadata = json.load(f)

print("UMAP metadata loaded:")
print(json.dumps(umap_metadata, indent=2))
# Out:
# UMAP metadata loaded:
# {
#   "id": "umap-007",
#   "embedding_id": "embedding-001",
#   "neighbors": 25,
#   "min_dist": 0.1,
#   "min_values": [
#     -1.246901512145996,
#     -3.9628655910491943
#   ],
#   "max_values": [
#     15.80892562866211,
#     9.830828666687012
#   ]
# }

# %%
min_values = np.array(umap_metadata['min_values'])
max_values = np.array(umap_metadata['max_values'])
normalized_points = (xy - min_values) / (max_values - min_values)
normalized_points = 2 * normalized_points - 1
results_df["x"] = normalized_points[:, 0]
results_df["y"] = normalized_points[:, 1]
results_df.head()
# Out:
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                              results  match_index         x  \
# 0  [0, 6915, 17590, 268, 6907, 6913, 14154, 6929,...            0  0.779924
# 1  [29, 38, 12630, 0, 12632, 12914, 3701, 50, 17,...            3 -0.062185
# 2  [38, 28, 0, 14156, 14202, 11426, 8646, 3685, 1...            2  0.068487
# 3       [0, 38, 28, 17, 3721, 4591, 9, 29, 40, 7239]            0 -0.076982
# 4         [38, 29, 17, 7, 9, 9560, 0, 11436, 30, 27]            6 -0.081414
#
#           y
# 0  0.529662
# 1 -0.242264
# 2 -0.030443
# 3 -0.317033
# 4 -0.346759

# %%
results_df.to_parquet(f"results/{scope['table_name']}.parquet")

# %%
# make sure the results are saved as int32
scope_id = "scopes-007"
metric = "cosine"
scope = json.load(open(f"scopes/{scope_id}_{metric}.json"))

# %%
test_df = pd.read_parquet(f"results/{scope['table_name']}.parquet")

# %%
test_df.head()
# Out:
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                              results  match_index         x  \
# 0  [0, 6915, 17590, 268, 6907, 6913, 14154, 6929,...            0  0.779924
# 1  [29, 38, 12630, 0, 12632, 12914, 3701, 50, 17,...            3 -0.062185
# 2  [38, 28, 0, 14156, 14202, 11426, 8646, 3685, 1...            2  0.068487
# 3       [0, 38, 28, 17, 3721, 4591, 9, 29, 40, 7239]            0 -0.076982
# 4         [38, 29, 17, 7, 9, 9560, 0, 11436, 30, 27]            6 -0.081414
#
#           y  answer_index
# 0  0.529662             0
# 1 -0.242264             0
# 2 -0.030443             0
# 3 -0.317033             0
# 4 -0.346759             0

# %%
test_df['results'] = test_df['results'].apply(lambda x: np.array(x, dtype=np.int32))
test_df.head()
# Out:
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                              results  match_index         x  \
# 0  [0, 6915, 17590, 268, 6907, 6913, 14154, 6929,...            0  0.779924
# 1  [29, 38, 12630, 0, 12632, 12914, 3701, 50, 17,...            3 -0.062185
# 2  [38, 28, 0, 14156, 14202, 11426, 8646, 3685, 1...            2  0.068487
# 3       [0, 38, 28, 17, 3721, 4591, 9, 29, 40, 7239]            0 -0.076982
# 4         [38, 29, 17, 7, 9, 9560, 0, 11436, 30, 27]            6 -0.081414
#
#           y  answer_index
# 0  0.529662             0
# 1 -0.242264             0
# 2 -0.030443             0
# 3 -0.317033             0
# 4 -0.346759             0

# %%
test_df.to_parquet(f"results/{scope['table_name']}.parquet")

# %%
# add the answer index for the question

context_df = pd.read_parquet(f"{scope["directory"]}/{scope['dataset']}/scopes/{scope_id}-input.parquet")
context_df.head()
# Out:
#    index                     title  \
# 0      0  University_of_Notre_Dame
# 1      1  University_of_Notre_Dame
# 2      2  University_of_Notre_Dame
# 3      3  University_of_Notre_Dame
# 4      4  University_of_Notre_Dame
#
#                                              context         x         y  \
# 0  Architecturally, the school has a Catholic cha...  0.779956  0.544280
# 1  As at most other universities, Notre Dame's st... -0.043100 -0.280547
# 2  The university is the major seat of the Congre... -0.049068 -0.314146
# 3  The College of Engineering was established in ... -0.080649 -0.305042
# 4  All of Notre Dame's undergraduate students are... -0.087783 -0.317861
#
#    cluster  raw_cluster                           label
# 0      137          137                  Mary Jesus God
# 1      252           -1         University city College
# 2      248          248  University university students
# 3      248          248  University university students
# 4      248          248  University university students

# %%
# Create a list to store the matching indices
# TODO: this could have just been i % 5 or something since the questions are in order and there are 5 questions per context
matching_indices = []

# Iterate through each row in test_df
for i, test_row in test_df.iterrows():
    # Get the question's context
    question_context = question_df.iloc[i]['context']
    
    # Find matching index in context_df
    match_idx = context_df[context_df['context'] == question_context].index
    
    # If match found, append the index, otherwise append -1
    if len(match_idx) > 0:
        matching_indices.append(match_idx[0])
    else:
        matching_indices.append(-1)

# %%
# matching_indices

# %%
# add answer_index
scope_id = "scopes-007"
metric = "cosine"
scope = json.load(open(f"scopes/{scope_id}_{metric}.json"))
test_df = pd.read_parquet(f"results/{scope['table_name']}.parquet")

# %%
# Add the matching indices as a new column
test_df['answer_index'] = matching_indices

# %%
test_df.head(10)
# Out:
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
# 5  When did the Scholastic Magazine of Notre dame...
# 6   How often is Notre Dame's the Juggler published?
# 7  What is the daily student paper at Notre Dame ...
# 8  How many student news papers are found at Notr...
# 9  In what year did the student paper Common Sens...
#
#                                              results  match_index         x  \
# 0  [0, 6915, 17590, 268, 6907, 6913, 14154, 6929,...            0  0.779924
# 1  [29, 38, 12630, 0, 12632, 12914, 3701, 50, 17,...            3 -0.062185
# 2  [38, 28, 0, 14156, 14202, 11426, 8646, 3685, 1...            2  0.068487
# 3       [0, 38, 28, 17, 3721, 4591, 9, 29, 40, 7239]            0 -0.076982
# 4         [38, 29, 17, 7, 9, 9560, 0, 11436, 30, 27]            6 -0.081414
# 5    [1, 8555, 38, 9832, 12548, 45, 26, 15, 9833, 9]            0 -0.082958
# 6  [1, 21, 38, 15, 12628, 8555, 17, 8557, 16515, ...            0 -0.097537
# 7  [1, 8555, 10591, 16515, 10516, 7946, 38, 10590...            0 -0.051903
# 8   [1, 15, 8555, 9, 8, 10516, 10591, 38, 16515, 40]            0 -0.056738
# 9      [1, 38, 8555, 8557, 29, 35, 616, 20248, 4, 6]            0 -0.082132
#
#           y  answer_index
# 0  0.529662             0
# 1 -0.242264             0
# 2 -0.030443             0
# 3 -0.317033             0
# 4 -0.346759             0
# 5 -0.327221             1
# 6 -0.362245             1
# 7 -0.286697             1
# 8 -0.311108             1
# 9 -0.316825             1

# %%
test_df.to_parquet(f"results/{scope['table_name']}.parquet")

# %%
print([round(x, 3) for x in embeddings[0][0:50].tolist()])
# Out:
# [-0.046, -0.02, -0.02, -0.001, 0.042, 0.066, 0.089, 0.086, -0.043, -0.067, 0.004, -0.025, 0.041, 0.042, -0.015, 0.049, 0.018, 0.03, -0.012, -0.062, 0.012, 0.021, -0.003, 0.004, -0.028, -0.016, 0.002, -0.007, -0.037, 0.001, 0.017, -0.011, 0.015, -0.05, -0.008, 0.0, -0.003, -0.044, -0.027, 0.02, -0.005, -0.057, 0.015, 0.061, -0.026, -0.025, 0.034, 0.058, -0.035, 0.046]
